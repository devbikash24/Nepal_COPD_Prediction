# %%
import numpy as np
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest,chi2

# %%
df=pd.read_csv("../data/final_dataset_after_featureeng.csv")

# %%
df.head()
# Out:
#    Age  Gender Smoking_Status  Biomass_Fuel_Exposure  Occupational_Exposure  \
# 0   31    Male         Former                      1                      1
# 1   60    Male          Never                      1                      0
# 2   33    Male         Former                      0                      0
# 3   36  Female        Current                      1                      0
# 4   58    Male          Never                      0                      0
#
#    Family_History_COPD    BMI   Location  Air_Pollution_Level  \
# 0                    1  27.56   Lalitpur                   84
# 1                    0  30.30    Pokhara                  131
# 2                    1  28.45    Pokhara                  123
# 3                    0  27.49  Kathmandu                  253
# 4                    0  25.49    Pokhara                  117
#
#    Respiratory_Infections_Childhood  COPD_Diagnosis Age_Category BMI_category  \
# 0                                 0               0        adult   overweight
# 1                                 1               0          old        obese
# 2                                 1               0        adult   overweight
# 3                                 0               1        adult   overweight
# 4                                 1               0  middle_aged   overweight
#
#   Air_Pollution_Level_category  Gender_encoded
# 0                 Satisfactory               1
# 1                     Moderate               1
# 2                     Moderate               1
# 3                         Poor               0
# 4                     Moderate               1

# %%
df=df.drop(columns=['Age','Gender','Air_Pollution_Level','BMI'])

# %%
df.head()
# Out:
#   Smoking_Status  Biomass_Fuel_Exposure  Occupational_Exposure  \
# 0         Former                      1                      1
# 1          Never                      1                      0
# 2         Former                      0                      0
# 3        Current                      1                      0
# 4          Never                      0                      0
#
#    Family_History_COPD   Location  Respiratory_Infections_Childhood  \
# 0                    1   Lalitpur                                 0
# 1                    0    Pokhara                                 1
# 2                    1    Pokhara                                 1
# 3                    0  Kathmandu                                 0
# 4                    0    Pokhara                                 1
#
#    COPD_Diagnosis Age_Category BMI_category Air_Pollution_Level_category  \
# 0               0        adult   overweight                 Satisfactory
# 1               0          old        obese                     Moderate
# 2               0        adult   overweight                     Moderate
# 3               1        adult   overweight                         Poor
# 4               0  middle_aged   overweight                     Moderate
#
#    Gender_encoded
# 0               1
# 1               1
# 2               1
# 3               0
# 4               1

# %%
features=df.columns.tolist()

# %%
features.remove('COPD_Diagnosis')
print(features)
# Out:
# ['Smoking_Status', 'Biomass_Fuel_Exposure', 'Occupational_Exposure', 'Family_History_COPD', 'Location', 'Respiratory_Infections_Childhood', 'Age_Category', 'BMI_category', 'Air_Pollution_Level_category', 'Gender_encoded']

# %%
X_train,X_test,y_train,y_test=train_test_split(df[features],df['COPD_Diagnosis'],test_size=0.2,random_state=42)

# %%
X_train.head()
# Out:
#     Smoking_Status  Biomass_Fuel_Exposure  Occupational_Exposure  \
# 29           Never                      0                      0
# 535        Current                      1                      0
# 695          Never                      1                      0
# 557         Former                      1                      0
# 836          Never                      0                      1
#
#      Family_History_COPD   Location  Respiratory_Infections_Childhood  \
# 29                     0    Hetauda                                 1
# 535                    1  Bhaktapur                                 1
# 695                    0     Butwal                                 1
# 557                    0  Bhaktapur                                 0
# 836                    0  Bhaktapur                                 0
#
#     Age_Category BMI_category Air_Pollution_Level_category  Gender_encoded
# 29   middle_aged   overweight                     Moderate               0
# 535        adult       normal                     Moderate               0
# 695      too_old       normal                 Satisfactory               0
# 557  middle_aged   overweight                     Moderate               1
# 836      too_old        obese                     Moderate               0

# %%
print(X_train.shape,X_test.shape)
# Out:
# (800, 10) (200, 10)

# %%
ohe = OneHotEncoder(sparse_output=False)
X_train_gender_city = ohe.fit_transform(X_train[['Location']])

# %%
X_train_gender_city.shape
# Out:
# (800, 10)

# %% [markdown]
# # Start with pipelining and using column Transformer

# %% [markdown]
# ### **I planned of Ordinal Encoding Smoking_Status, Age_Category,	BMI_category, Air_Pollution_Level_category**

# %%
trf1=ColumnTransformer([
    ('oe_columns',OrdinalEncoder(categories=[['Never','Former','Current'],['young','adult','middle_aged','old','too_old'],['underweight','normal','overweight','obese','too_obese'],['Good','Satisfactory','Moderate','Poor','Very_Poor','Severe']]),[0,6,7,8]),
    ('ohe_Location',OneHotEncoder(sparse_output=False,handle_unknown='ignore'),[4])
],remainder='passthrough')

# %%
# Feature selection
trf2 = SelectKBest(score_func=chi2,k=8)

# %%
# create the pipeline
pipe = Pipeline([
    ('trf1',trf1),
    ('trf2',trf2)
])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('oe_columns',
#                                                   OrdinalEncoder(categories=[['Never',
#                                                                               'Former',
#                                                                               'Current'],
#                                                                              ['young',
#                                                                               'adult',
#                                                                               'middle_aged',
#                                                                               'old',
#                                                                               'too_old'],
#                                                                              ['underweight',
#                                                                               'normal',
#                                                                               'overweight',
#                                                                               'obese',
#                                                                               'too_obese'],
#                                                                              ['Good',
#                                                                               'Satisfactory',
#                                                                               'Moderate',
#                                                                               'Poor',
#                                                                               'Very_Poor',
#                                                                               'Severe']]),
#                                                   [0, 6, 7, 8]),
#                                                  ('ohe_Location',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [4])])),
#                 ('trf2',
#                  SelectKBest(k=8,
#                              score_func=<function chi2 at 0x00000265DCBB9D00>))])

# %%
import pickle
pickle.dump(pipe,open('../models/pipe.pkl','wb'))

# %%
df.to_csv('../models/final_dataset_after_pipelining.csv', index=False)
